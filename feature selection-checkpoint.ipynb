# %%
import pandas as pd #import panda
df1 = pd.read_csv('test_data.csv')
df2 = pd.read_csv('train_data.csv')

# %%
f_train_data = pd.concat([df1, df2],axis=0)

# %%
f_train_data.shape
# Out:
# (2919, 77)

# %%
df1.shape
# Out:
# (1459, 76)

# %%
encode_T = pd.DataFrame(pd.get_dummies(f_train_data))

# %%
encode_T
# Out:
#         Id  LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0     1461     0.590909    0.000000    0.155939  144.000000  -0.328436
# 1     1462     0.636364    0.658537    0.759788    0.000000  -0.093345
# 2     1463     0.318182    0.000000    0.584605    0.000000  -0.558341
# 3     1464     0.500000    0.121951    0.333776    0.000000  -0.235091
# 4     1465    -1.090909    0.000000   -0.116125    0.000000   0.962835
# ...    ...          ...         ...         ...         ...        ...
# 1455  1456    -0.333333    0.000000    0.000000    0.000000   0.407962
# 1456  1457     0.761905    0.716867    0.139972    0.110583   0.252140
# 1457  1458    -0.142857    0.000000    0.048724    0.000000   0.375428
# 1458  1459    -0.047619    0.000000    0.008682    0.698100   0.000000
# 1459  1460     0.285714    0.000000    0.147059    0.196744   0.058219
#
#       TotalBsmtSF  BsmtFullBath  BsmtHalfBath  GarageYrBlt  ...  \
# ...

# %%
df_tr = encode_T.drop_duplicates()

# %%
df_tr.shape
# Out:
# (2919, 277)

# %%
import seaborn as sns
sns.heatmap(df_tr.isnull(),cbar=False)

# %%
na_fea =pd.DataFrame(df_tr.isnull().sum(),columns=['na_count'])

# %%
for (row,rowdata) in na_fea.iterrows():
    if int(rowdata["na_count"])> 0:
        print(row)
# Out:
# SalePrice

# %%
df1 = df_tr[df_tr.isna().any(axis=1)]

# %%
df_evaluate = pd.DataFrame(df_tr[df_tr['SalePrice'].isna()])

# %%
df_evaluate = df_evaluate.drop("SalePrice",axis=1)

# %%
sns.heatmap(df_evaluate.isnull(),cbar=False)

# %%
train_f =df_tr.dropna()

# %%
train_f
# Out:
#         Id  LotFrontage  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        1    -0.190476    1.180723    0.125089    0.000000   0.064212
# 1        2     0.523810    0.000000    0.173281    0.000000   0.121575
# 2        3    -0.047619    0.975904    0.086109    0.000000   0.185788
# 3        4    -0.428571    0.000000    0.038271    0.000000   0.231164
# 4        5     0.714286    2.108434    0.116052    0.000000   0.209760
# ...    ...          ...         ...         ...         ...        ...
# 1455  1456    -0.333333    0.000000    0.000000    0.000000   0.407962
# 1456  1457     0.761905    0.716867    0.139972    0.110583   0.252140
# 1457  1458    -0.142857    0.000000    0.048724    0.000000   0.375428
# 1458  1459    -0.047619    0.000000    0.008682    0.698100   0.000000
# 1459  1460     0.285714    0.000000    0.147059    0.196744   0.058219
#
#       TotalBsmtSF  BsmtFullBath  BsmtHalfBath  GarageYrBlt  ...  \
# ...

# %%
# train data set : train_f
# test data set : df_evaluate
train_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Columns: 277 entries, Id to SaleCondition_Partial
# dtypes: float64(37), int64(1), uint8(239)
# memory usage: 785.6 KB

# %%
y=train_f['SalePrice']
X=train_f.drop(['SalePrice','Id'],axis=1)

# %%
list(X.columns.values)
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'MSZoning_C (all)',
#  'MSZoning_FV',
#  'MSZoning_RH',
#  'MSZoning_RL',
#  'MSZoning_RM',
#  'Street_Grvl',
#  'Street_Pave',
#  'LotShape_IR1',
#  'LotShape_IR2',
#  'LotShape_IR3',
#  'LotShape_Reg',
#  'LandContour_Bnk',
#  'LandContour_HLS',
#  'LandContour_Low',
#  'LandContour_Lvl',
#  'Utilities_AllPub',
#  'Utilities_NoSeWa',
#  'LotConfig_Corner',
#  'LotConfig_CulDSac',
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LassoCV

lasso = LassoCV().fit(X, y)
importance = pd.DataFrame(np.abs(lasso.coef_),columns=['inpotance'])
feature_names =pd.DataFrame(np.array(X.columns),columns=['features'])

n_X =  pd.concat([feature_names,importance],axis=1)

# %%
n_X
# Out:
#                   features    inpotance
# 0              LotFrontage     0.000000
# 1               MasVnrArea  3940.823263
# 2               BsmtFinSF1     0.000000
# 3               BsmtFinSF2     0.000000
# 4                BsmtUnfSF     0.000000
# ..                     ...          ...
# 270  SaleCondition_AdjLand     0.000000
# 271   SaleCondition_Alloca     0.000000
# 272   SaleCondition_Family     0.000000
# 273   SaleCondition_Normal     0.000000
# 274  SaleCondition_Partial     0.000000
#
# [275 rows x 2 columns]

# %%
n_X1  = n_X[n_X['inpotance']>0.000000]

# %%
n_X1
# Out:
#                   features     inpotance
# 1               MasVnrArea   3940.823263
# 6             BsmtFullBath  16375.404930
# 8              GarageYrBlt    553.633186
# 9               GarageCars  33869.581760
# 10              GarageArea   2650.721221
# ..                     ...           ...
# 256          GarageCond_TA   2147.135087
# 259           PavedDrive_Y     23.176637
# 266           SaleType_New  10214.020443
# 268            SaleType_WD   2470.165703
# 269  SaleCondition_Abnorml   5670.344494
#
# [82 rows x 2 columns]

# %%
list(n_X1['features'])
# Out:
# ['MasVnrArea',
#  'BsmtFullBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'HalfBath',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'WoodDeckSF',
#  'ScreenPorch',
#  'MoSold',
#  'YrSold',
#  'MSZoning_C (all)',
#  'MSZoning_RL',
#  'MSZoning_RM',
#  'LotShape_IR2',
#  'LandContour_Bnk',
#  'LotConfig_CulDSac',
#  'LotConfig_FR2',
#  'LandSlope_Gtl',
#  'Neighborhood_BrkSide',
#  'Neighborhood_Crawfor',
#  'Neighborhood_Edwards',
#  'Neighborhood_Gilbert',
#  'Neighborhood_Mitchel',
#  'Neighborhood_NAmes',
#  'Neighborhood_NoRidge',
#  'Neighborhood_NridgHt',
#  'Neighborhood_OldTown',
#  'Neighborhood_Somerst',
#  'Neighborhood_StoneBr',
#  'Condition1_Norm',
#  'Condition2_PosN',
#  'BldgType_1Fam',
#  'HouseStyle_1Story',
#  'HouseStyle_2Story',
#  'RoofStyle_Gable',
#  'RoofStyle_Hip',
#  'RoofMatl_ClyTile',
#  'RoofMatl_WdShngl',
# ...

# %%
 r1x = X[list(n_X1['features'])]

# %%
 r1x
# Out:
#       MasVnrArea  BsmtFullBath  GarageYrBlt  GarageCars  GarageArea  \
# 0       1.180723      0.333333     0.560976        0.50    0.386460
# 1       0.000000      0.000000    -0.097561        0.50    0.324401
# 2       0.975904      0.333333     0.512195        0.50    0.428773
# 3       0.000000      0.333333     0.439024        0.75    0.452750
# 4       2.108434      0.333333     0.487805        0.75    0.589563
# ...          ...           ...          ...         ...         ...
# 1455    0.000000      0.000000     0.463415        0.50    0.324401
# 1456    0.716867      0.333333    -0.048780        0.50    0.352609
# 1457    0.000000      0.000000    -0.951220        0.25    0.177715
# 1458    0.000000      0.333333    -0.731707        0.25    0.169252
# 1459    0.000000      0.333333    -0.365854        0.25    0.194640
#
#       MSSubClass  OverallQual  OverallCond  YearBuilt  YearRemodAdd  ...  \
# 0       0.235294     0.666667        0.500   0.949275      0.883333  ...
# ...

# %%
df_evaluate = df_evaluate[list(n_X1['features'])]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error
import numpy as NP

# %%
grid_param = {

    'bootstrap' : [True],

    'max_depth': [10,20,30],

    'max_features': [50,60,70],

    'min_samples_leaf': [2,3],

    'min_samples_split': [10],

    'n_estimators': [10000]

}

# %%
 X_train, X_test, y_train, y_test = train_test_split(
        r1x , y, test_size=0.5, random_state=0) 
regr = RandomForestRegressor(random_state=0)
clf = RandomizedSearchCV(regr,param_distributions=grid_param,n_iter=10, cv=3,random_state=0)
model= clf.fit( X_train,y_train)
y_pred = model.predict(X_test)
MSE=mean_squared_error(y_test,y_pred)
RMSE = NP.sqrt(MSE)
print("RSME =",RMSE)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-4a0b221530af> in <module>
#       3 regr = RandomForestRegressor(random_state=0)
#       4 clf = RandomizedSearchCV(regr,param_distributions=grid_param,n_iter=10, cv=3,random_state=0)
# ----> 5 model= clf.fit( X_train,y_train)
#       6 y_pred = model.predict(X_test)
#       7 MSE=mean_squared_error(y_test,y_pred)
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# D:\Anaconda\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# ...

# %%
#model creation,
grid_param = {

    'bootstrap' : [True],

    'max_depth': [10,20,30],

    'max_features': [50,60,70],

    'min_samples_leaf': [2,3],

    'min_samples_split': [10],

    'n_estimators': [10000]

}
regr1 = RandomForestRegressor(random_state=0)
clf1 = RandomizedSearchCV(regr1,param_distributions=grid_param,n_iter=10, cv=5,random_state=0)
model= clf.fit( r1x,y)
y_pred = model.predict(df_evaluate)

# %%
y_pred
# Out:
# array([315778.14416292, 309682.49917131, 358888.47096757, ...,
#        314362.97850152, 309338.95692181, 411415.20542101])

# %%
pred=pd.DataFrame(y_pred)
sub_df=pd.read_csv('sample_submission.csv')
datasets=pd.concat([sub_df['Id'],pred],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)
